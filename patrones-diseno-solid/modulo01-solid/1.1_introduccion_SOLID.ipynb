// %% [markdown]
// # 🧩 1.1 – Introducción a los Principios SOLID
//
// Los **principios SOLID** son un conjunto de buenas prácticas en el diseño orientado a objetos que permiten crear software **más mantenible, flexible y escalable**.
//
// Estos principios fueron popularizados por **Robert C. Martin (Uncle Bob)** y representan una guía para escribir código limpio y extensible.
//
// ---
// ## 🎯 Objetivos del notebook
// - Comprender qué son los principios SOLID.
// - Entender por qué son importantes en el diseño de software.
// - Conocer el significado de cada letra del acrónimo.
// - Identificar situaciones donde su aplicación mejora el diseño.

// %%
console.log('✅ Notebook 1.1 – Introducción a los Principios SOLID listo para usar.');

// %% [markdown]
// ---
// ## 1️⃣ ¿Qué es SOLID?
//
// El acrónimo **SOLID** representa cinco principios clave del diseño orientado a objetos:
//
// | Letra | Principio | Descripción breve |
// |:------|:-----------|:-----------------|
// | **S** | *Single Responsibility Principle* | Cada clase debe tener una única responsabilidad o motivo de cambio. |
// | **O** | *Open/Closed Principle* | Las clases deben estar abiertas a extensión, pero cerradas a modificación. |
// | **L** | *Liskov Substitution Principle* | Los objetos derivados deben poder sustituir a sus clases base sin alterar el comportamiento. |
// | **I** | *Interface Segregation Principle* | Las interfaces deben ser específicas y no forzar la implementación de métodos innecesarios. |
// | **D** | *Dependency Inversion Principle* | Los módulos de alto nivel deben depender de abstracciones, no de implementaciones concretas. |

// %% [markdown]
// �� **Idea central:** aplicar SOLID reduce el acoplamiento entre componentes y mejora la reutilización del código.
//
// Estos principios no son reglas estrictas, sino guías que ayudan a tomar mejores decisiones de diseño.

// %% [markdown]
// ---
// ## 2️⃣ Ventajas de aplicar SOLID
//
// 1. **Mayor mantenibilidad:** los cambios en una parte del código afectan menos a otras.
// 2. **Facilidad para añadir nuevas funcionalidades.**
// 3. **Mejor reutilización y testabilidad.**
// 4. **Menor acoplamiento y mayor cohesión.**
//
// 💡 En resumen, SOLID busca **mejorar la calidad del software**, no su rendimiento de ejecución, sino su **escalabilidad y facilidad de evolución**.

// %% [markdown]
// ---
// ## 3️⃣ 🧩 Ejemplo ilustrativo
//
// Veamos un ejemplo de código **sin aplicar SOLID**:

// %%
// ❌ Ejemplo: clase con múltiples responsabilidades (violando SRP)
class Order {
  constructor(public items: string[]) {}
  calculateTotal() { return this.items.length * 10; }
  printInvoice() { console.log('Factura generada'); }
  saveToDatabase() { console.log('Guardando en base de datos...'); }
}

const order = new Order(['Teclado', 'Ratón']);
order.saveToDatabase();
// Out:
// Guardando en base de datos...

// %% [markdown]
// 🧠 Esta clase hace **demasiadas cosas**: cálculo, presentación y persistencia.
// Cada cambio (por ejemplo, cambiar el formato de impresión o el método de guardado) afectará toda la clase.
//
// 👉 Aplicando el principio **S (Single Responsibility)**, separaríamos responsabilidades en clases distintas.

// %% [markdown]
// ---
// ## 4️⃣ 💬 Pregunta de reflexión
//
// ¿Cuál crees que es el **objetivo principal** de aplicar los principios SOLID?
//
// A) Acelerar la compilación del código
// ✅ B) Mejorar la mantenibilidad y escalabilidad del software
// C) Reducir el número de clases
// D) Aumentar el rendimiento de ejecución
//
// �� La opción correcta es **B**, porque SOLID se centra en **hacer que el código sea más fácil de mantener, probar y extender**.

// %% [markdown]
// ---
// ## 🧠 Resumen del notebook
//
// - **SOLID** es un conjunto de 5 principios para mejorar el diseño de software orientado a objetos.
// - Facilitan la **mantenibilidad, extensibilidad y reutilización**.
// - No son reglas, sino **guías prácticas** para escribir código limpio.
//
// ➡️ Próximo notebook → **1.2 – Principios SOLID en Acción** (con ejemplos de cada principio en TypeScript).
